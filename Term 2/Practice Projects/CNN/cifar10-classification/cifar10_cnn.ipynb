# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 26s - loss: 1.6235 - acc: 0.4102 - val_loss: 1.4759 - val_acc: 0.4778
#
# Epoch 00001: val_loss improved from inf to 1.47592, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 26s - loss: 1.3014 - acc: 0.5320 - val_loss: 1.1748 - val_acc: 0.5832
#
# Epoch 00002: val_loss improved from 1.47592 to 1.17476, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 27s - loss: 1.1726 - acc: 0.5819 - val_loss: 1.1636 - val_acc: 0.5880
#
# Epoch 00003: val_loss improved from 1.17476 to 1.16361, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 27s - loss: 1.1025 - acc: 0.6107 - val_loss: 1.0951 - val_acc: 0.6172
#
# Epoch 00004: val_loss improved from 1.16361 to 1.09507, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 26s - loss: 1.0609 - acc: 0.6294 - val_loss: 1.0834 - val_acc: 0.6328
#
# Epoch 00005: val_loss improved from 1.09507 to 1.08338, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 25s - loss: 1.0346 - acc: 0.6406 - val_loss: 1.0244 - val_acc: 0.6536
#
# Epoch 00006: val_loss improved from 1.08338 to 1.02442, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 24s - loss: 1.0185 - acc: 0.6489 - val_loss: 1.0045 - val_acc: 0.6650
#
# Epoch 00007: val_loss improved from 1.02442 to 1.00455, saving model to model.weights.best.hdf5
# Epoch 8/100
#  - 24s - loss: 1.0119 - acc: 0.6523 - val_loss: 1.0315 - val_acc: 0.6556
#
# Epoch 00008: val_loss did not improve from 1.00455
# Epoch 9/100
#  - 24s - loss: 1.0156 - acc: 0.6542 - val_loss: 1.0723 - val_acc: 0.6378
#
# Epoch 00009: val_loss did not improve from 1.00455
# Epoch 10/100
#  - 24s - loss: 1.0205 - acc: 0.6567 - val_loss: 0.9608 - val_acc: 0.6812
#
# Epoch 00010: val_loss improved from 1.00455 to 0.96078, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 28s - loss: 1.0331 - acc: 0.6534 - val_loss: 1.0746 - val_acc: 0.6498
#
# Epoch 00011: val_loss did not improve from 0.96078
# Epoch 12/100
#  - 27s - loss: 1.0421 - acc: 0.6495 - val_loss: 0.9185 - val_acc: 0.6882
#
# Epoch 00012: val_loss improved from 0.96078 to 0.91853, saving model to model.weights.best.hdf5
# Epoch 13/100
#  - 28s - loss: 1.0537 - acc: 0.6459 - val_loss: 1.0710 - val_acc: 0.6476
#
# Epoch 00013: val_loss did not improve from 0.91853
# Epoch 14/100
#  - 27s - loss: 1.0669 - acc: 0.6429 - val_loss: 0.9421 - val_acc: 0.6772
#
# Epoch 00014: val_loss did not improve from 0.91853
# Epoch 15/100
#  - 24s - loss: 1.1011 - acc: 0.6317 - val_loss: 1.0841 - val_acc: 0.6466
#
# Epoch 00015: val_loss did not improve from 0.91853
# Epoch 16/100
#  - 24s - loss: 1.1027 - acc: 0.6310 - val_loss: 1.4326 - val_acc: 0.5478
#
# Epoch 00016: val_loss did not improve from 0.91853
# Epoch 17/100
#  - 24s - loss: 1.1222 - acc: 0.6291 - val_loss: 1.1068 - val_acc: 0.6514
#
# Epoch 00017: val_loss did not improve from 0.91853
# Epoch 18/100
#  - 24s - loss: 1.1409 - acc: 0.6242 - val_loss: 1.1772 - val_acc: 0.6514
#
# Epoch 00018: val_loss did not improve from 0.91853
# Epoch 19/100
#  - 24s - loss: 1.1609 - acc: 0.6154 - val_loss: 1.1227 - val_acc: 0.6620
#
# Epoch 00019: val_loss did not improve from 0.91853
# Epoch 20/100
#  - 23s - loss: 1.1878 - acc: 0.6094 - val_loss: 1.4565 - val_acc: 0.6130
#
# Epoch 00020: val_loss did not improve from 0.91853
# Epoch 21/100
#  - 23s - loss: 1.2056 - acc: 0.6036 - val_loss: 1.2241 - val_acc: 0.6080
#
# Epoch 00021: val_loss did not improve from 0.91853
# Epoch 22/100
#  - 23s - loss: 1.2225 - acc: 0.5951 - val_loss: 1.2083 - val_acc: 0.5996
#
# Epoch 00022: val_loss did not improve from 0.91853
# Epoch 23/100
#  - 23s - loss: 1.2436 - acc: 0.5905 - val_loss: 1.1635 - val_acc: 0.5986
#
# Epoch 00023: val_loss did not improve from 0.91853
# Epoch 24/100
#  - 23s - loss: 1.2701 - acc: 0.5819 - val_loss: 1.1760 - val_acc: 0.6122
#
# Epoch 00024: val_loss did not improve from 0.91853
# Epoch 25/100
#  - 24s - loss: 1.2851 - acc: 0.5762 - val_loss: 1.3145 - val_acc: 0.6010
#
# Epoch 00025: val_loss did not improve from 0.91853
# Epoch 26/100
#  - 24s - loss: 1.2968 - acc: 0.5721 - val_loss: 1.1321 - val_acc: 0.6370
#
# Epoch 00026: val_loss did not improve from 0.91853
# Epoch 27/100
#  - 24s - loss: 1.3204 - acc: 0.5672 - val_loss: 1.7767 - val_acc: 0.5598
#
# Epoch 00027: val_loss did not improve from 0.91853
# Epoch 28/100
#  - 23s - loss: 1.3336 - acc: 0.5557 - val_loss: 1.1814 - val_acc: 0.6160
#
# Epoch 00028: val_loss did not improve from 0.91853
# Epoch 29/100
#  - 24s - loss: 1.3668 - acc: 0.5491 - val_loss: 1.3021 - val_acc: 0.5702
#
# Epoch 00029: val_loss did not improve from 0.91853
# Epoch 30/100
#  - 24s - loss: 1.3823 - acc: 0.5448 - val_loss: 1.1675 - val_acc: 0.6392
#
# Epoch 00030: val_loss did not improve from 0.91853
# Epoch 31/100
#  - 26s - loss: 1.4027 - acc: 0.5383 - val_loss: 1.6365 - val_acc: 0.5226
#
# Epoch 00031: val_loss did not improve from 0.91853
# Epoch 32/100
#  - 24s - loss: 1.3893 - acc: 0.5406 - val_loss: 1.5659 - val_acc: 0.5388
#
# Epoch 00032: val_loss did not improve from 0.91853
# Epoch 33/100
#  - 23s - loss: 1.4100 - acc: 0.5332 - val_loss: 1.5871 - val_acc: 0.4996
#
# Epoch 00033: val_loss did not improve from 0.91853
# Epoch 34/100
#  - 24s - loss: 1.4213 - acc: 0.5280 - val_loss: 1.3352 - val_acc: 0.5568
#
# Epoch 00034: val_loss did not improve from 0.91853
# Epoch 35/100
#  - 24s - loss: 1.4276 - acc: 0.5278 - val_loss: 1.2925 - val_acc: 0.5710
#
# Epoch 00035: val_loss did not improve from 0.91853
# Epoch 36/100
#  - 24s - loss: 1.4458 - acc: 0.5229 - val_loss: 1.6660 - val_acc: 0.4572
#
# Epoch 00036: val_loss did not improve from 0.91853
# Epoch 37/100
#  - 25s - loss: 1.4539 - acc: 0.5172 - val_loss: 1.6651 - val_acc: 0.4800
#
# Epoch 00037: val_loss did not improve from 0.91853
# Epoch 38/100
#  - 23s - loss: 1.4599 - acc: 0.5167 - val_loss: 1.3410 - val_acc: 0.5584
#
# Epoch 00038: val_loss did not improve from 0.91853
# Epoch 39/100
#  - 24s - loss: 1.4812 - acc: 0.5074 - val_loss: 1.6253 - val_acc: 0.5036
#
# Epoch 00039: val_loss did not improve from 0.91853
# Epoch 40/100
#  - 24s - loss: 1.4958 - acc: 0.5030 - val_loss: 1.3136 - val_acc: 0.5670
#
# Epoch 00040: val_loss did not improve from 0.91853
# Epoch 41/100
#  - 23s - loss: 1.4949 - acc: 0.5013 - val_loss: 1.3154 - val_acc: 0.5694
#
# Epoch 00041: val_loss did not improve from 0.91853
# Epoch 42/100
#  - 23s - loss: 1.4909 - acc: 0.5023 - val_loss: 1.8705 - val_acc: 0.5784
#
# Epoch 00042: val_loss did not improve from 0.91853
# Epoch 43/100
#  - 24s - loss: 1.5199 - acc: 0.4953 - val_loss: 1.5025 - val_acc: 0.4330
#
# Epoch 00043: val_loss did not improve from 0.91853
# Epoch 44/100
#  - 24s - loss: 1.5271 - acc: 0.4922 - val_loss: 1.2131 - val_acc: 0.5784
#
# Epoch 00044: val_loss did not improve from 0.91853
# Epoch 45/100
#  - 23s - loss: 1.5385 - acc: 0.4909 - val_loss: 1.2310 - val_acc: 0.5790
#
# Epoch 00045: val_loss did not improve from 0.91853
# Epoch 46/100
#  - 24s - loss: 1.5510 - acc: 0.4816 - val_loss: 1.3977 - val_acc: 0.5288
#
# Epoch 00046: val_loss did not improve from 0.91853
# Epoch 47/100
#  - 26s - loss: 1.5542 - acc: 0.4825 - val_loss: 1.3381 - val_acc: 0.5638
#
# Epoch 00047: val_loss did not improve from 0.91853
# Epoch 48/100
#  - 30s - loss: 1.5655 - acc: 0.4748 - val_loss: 1.4138 - val_acc: 0.5036
#
# Epoch 00048: val_loss did not improve from 0.91853
# Epoch 49/100
#  - 24s - loss: 1.5845 - acc: 0.4736 - val_loss: 1.5590 - val_acc: 0.4756
#
# Epoch 00049: val_loss did not improve from 0.91853
# Epoch 50/100
#  - 24s - loss: 1.5773 - acc: 0.4719 - val_loss: 1.5923 - val_acc: 0.4588
#
# Epoch 00050: val_loss did not improve from 0.91853
# Epoch 51/100
#  - 24s - loss: 1.5857 - acc: 0.4686 - val_loss: 1.7467 - val_acc: 0.4650
#
# Epoch 00051: val_loss did not improve from 0.91853
# Epoch 52/100
#  - 24s - loss: 1.5904 - acc: 0.4660 - val_loss: 1.5940 - val_acc: 0.4850
#
# Epoch 00052: val_loss did not improve from 0.91853
# Epoch 53/100
#  - 24s - loss: 1.6106 - acc: 0.4609 - val_loss: 1.5226 - val_acc: 0.4848
#
# Epoch 00053: val_loss did not improve from 0.91853
# Epoch 54/100
#  - 24s - loss: 1.6058 - acc: 0.4614 - val_loss: 1.3639 - val_acc: 0.5392
#
# Epoch 00054: val_loss did not improve from 0.91853
# Epoch 55/100
#  - 24s - loss: 1.6092 - acc: 0.4555 - val_loss: 1.7089 - val_acc: 0.4726
#
# Epoch 00055: val_loss did not improve from 0.91853
# Epoch 56/100
#  - 23s - loss: 1.6349 - acc: 0.4473 - val_loss: 1.8841 - val_acc: 0.4544
#
# Epoch 00056: val_loss did not improve from 0.91853
# Epoch 57/100
#  - 24s - loss: 1.6515 - acc: 0.4463 - val_loss: 1.9199 - val_acc: 0.4586
# Epoch 00057: val_loss did not improve from 0.91853
# Epoch 58/100
#  - 24s - loss: 1.6626 - acc: 0.4404 - val_loss: 1.4853 - val_acc: 0.4978
#
# Epoch 00058: val_loss did not improve from 0.91853
# Epoch 59/100
#  - 24s - loss: 1.6900 - acc: 0.4305 - val_loss: 1.4623 - val_acc: 0.5334
#
# Epoch 00059: val_loss did not improve from 0.91853
# Epoch 60/100
#  - 24s - loss: 1.6998 - acc: 0.4299 - val_loss: 1.6469 - val_acc: 0.4288
#
# Epoch 00060: val_loss did not improve from 0.91853
# Epoch 61/100
#  - 24s - loss: 1.7120 - acc: 0.4174 - val_loss: 1.6122 - val_acc: 0.4508
#
# Epoch 00061: val_loss did not improve from 0.91853
# Epoch 62/100
#  - 24s - loss: 1.7245 - acc: 0.4220 - val_loss: 1.4374 - val_acc: 0.5050
#
# Epoch 00062: val_loss did not improve from 0.91853
# Epoch 63/100
#  - 24s - loss: 1.7293 - acc: 0.4094 - val_loss: 1.4631 - val_acc: 0.4868
#
# Epoch 00063: val_loss did not improve from 0.91853
# Epoch 64/100
#  - 24s - loss: 1.7308 - acc: 0.4131 - val_loss: 2.0243 - val_acc: 0.2944
#
# Epoch 00064: val_loss did not improve from 0.91853
# Epoch 65/100
#  - 27s - loss: 1.7381 - acc: 0.4097 - val_loss: 1.6197 - val_acc: 0.4048
#
# Epoch 00065: val_loss did not improve from 0.91853
# Epoch 66/100
#  - 27s - loss: 1.7436 - acc: 0.4053 - val_loss: 1.6926 - val_acc: 0.4008
#
# Epoch 00066: val_loss did not improve from 0.91853
# Epoch 67/100
#  - 25s - loss: 1.7598 - acc: 0.3978 - val_loss: 1.7217 - val_acc: 0.4126
#
# Epoch 00067: val_loss did not improve from 0.91853
# Epoch 68/100
#  - 24s - loss: 1.7596 - acc: 0.3977 - val_loss: 1.5712 - val_acc: 0.4372
#
# Epoch 00068: val_loss did not improve from 0.91853
# Epoch 69/100
#  - 24s - loss: 1.7947 - acc: 0.3901 - val_loss: 1.6506 - val_acc: 0.4194
#
# Epoch 00069: val_loss did not improve from 0.91853
# Epoch 70/100
#  - 24s - loss: 1.7881 - acc: 0.3885 - val_loss: 1.5624 - val_acc: 0.4208
#
# Epoch 00070: val_loss did not improve from 0.91853
# Epoch 71/100
#  - 24s - loss: 1.7836 - acc: 0.3803 - val_loss: 1.5563 - val_acc: 0.4400
#
# Epoch 00071: val_loss did not improve from 0.91853
# Epoch 72/100
#  - 25s - loss: 1.8050 - acc: 0.3752 - val_loss: 1.8153 - val_acc: 0.4320
#
# Epoch 00072: val_loss did not improve from 0.91853
# Epoch 73/100
#  - 24s - loss: 1.8220 - acc: 0.3684 - val_loss: 1.6975 - val_acc: 0.4180
#
# Epoch 00073: val_loss did not improve from 0.91853
# Epoch 74/100
#  - 24s - loss: 1.8242 - acc: 0.3633 - val_loss: 1.5356 - val_acc: 0.4466
#
# Epoch 00074: val_loss did not improve from 0.91853
# Epoch 75/100
#  - 24s - loss: 1.8498 - acc: 0.3638 - val_loss: 1.8709 - val_acc: 0.3322
#
# Epoch 00075: val_loss did not improve from 0.91853
# Epoch 76/100
#  - 24s - loss: 1.8421 - acc: 0.3643 - val_loss: 1.6398 - val_acc: 0.4084
#
# Epoch 00076: val_loss did not improve from 0.91853
# Epoch 77/100
#  - 24s - loss: 1.8623 - acc: 0.3541 - val_loss: 1.6048 - val_acc: 0.4340
#
# Epoch 00077: val_loss did not improve from 0.91853
# Epoch 78/100
#  - 24s - loss: 1.8583 - acc: 0.3620 - val_loss: 1.5656 - val_acc: 0.4272
#
# Epoch 00078: val_loss did not improve from 0.91853
# Epoch 79/100
#  - 24s - loss: 1.8426 - acc: 0.3516 - val_loss: 1.5374 - val_acc: 0.4444
#
# Epoch 00079: val_loss did not improve from 0.91853
# Epoch 80/100
#  - 24s - loss: 1.8482 - acc: 0.3528 - val_loss: 1.6905 - val_acc: 0.4038
#
# Epoch 00080: val_loss did not improve from 0.91853
# Epoch 81/100
#  - 24s - loss: 1.8549 - acc: 0.3489 - val_loss: 1.7066 - val_acc: 0.4078
#
# Epoch 00081: val_loss did not improve from 0.91853
# Epoch 82/100
#  - 24s - loss: 1.8555 - acc: 0.3520 - val_loss: 1.6223 - val_acc: 0.4016
#
# Epoch 00082: val_loss did not improve from 0.91853
# Epoch 83/100
#  - 24s - loss: 1.8623 - acc: 0.3495 - val_loss: 1.6789 - val_acc: 0.3906
#
# Epoch 00083: val_loss did not improve from 0.91853
# Epoch 84/100
#  - 26s - loss: 1.8642 - acc: 0.3449 - val_loss: 4.0475 - val_acc: 0.3372
#
# Epoch 00084: val_loss did not improve from 0.91853
# Epoch 85/100
#  - 24s - loss: 1.8732 - acc: 0.3396 - val_loss: 2.4837 - val_acc: 0.3666
#
# Epoch 00085: val_loss did not improve from 0.91853
# Epoch 86/100
#  - 24s - loss: 1.8667 - acc: 0.3421 - val_loss: 1.8737 - val_acc: 0.3268
#
# Epoch 00086: val_loss did not improve from 0.91853
# Epoch 87/100
#  - 25s - loss: 1.8888 - acc: 0.3375 - val_loss: 1.7216 - val_acc: 0.4034
#
# Epoch 00087: val_loss did not improve from 0.91853
# Epoch 88/100
#  - 23s - loss: 1.8954 - acc: 0.3350 - val_loss: 1.6566 - val_acc: 0.4094
#
# Epoch 00088: val_loss did not improve from 0.91853
# Epoch 89/100
#  - 24s - loss: 1.8844 - acc: 0.3367 - val_loss: 1.8147 - val_acc: 0.3368
#
# Epoch 00089: val_loss did not improve from 0.91853
# Epoch 90/100
#  - 23s - loss: 1.8930 - acc: 0.3292 - val_loss: 1.6924 - val_acc: 0.3634
#
# Epoch 00090: val_loss did not improve from 0.91853
# Epoch 91/100
#  - 23s - loss: 1.8902 - acc: 0.3206 - val_loss: 1.8426 - val_acc: 0.3468
#
# Epoch 00091: val_loss did not improve from 0.91853
# Epoch 92/100
#  - 25s - loss: 1.9056 - acc: 0.3188 - val_loss: 1.7256 - val_acc: 0.4078
#
# Epoch 00092: val_loss did not improve from 0.91853
# Epoch 93/100
#  - 24s - loss: 1.9065 - acc: 0.3180 - val_loss: 1.6497 - val_acc: 0.3920
#
# Epoch 00093: val_loss did not improve from 0.91853
# Epoch 94/100
#  - 24s - loss: 1.9083 - acc: 0.3145 - val_loss: 2.0783 - val_acc: 0.3294
#
# Epoch 00094: val_loss did not improve from 0.91853
# Epoch 95/100
#  - 24s - loss: 1.8960 - acc: 0.3202 - val_loss: 1.7399 - val_acc: 0.3588
#
# Epoch 00095: val_loss did not improve from 0.91853
# Epoch 96/100
#  - 29s - loss: 1.8955 - acc: 0.3140 - val_loss: 1.8183 - val_acc: 0.3700
#
# Epoch 00096: val_loss did not improve from 0.91853
# Epoch 97/100
#  - 28s - loss: 1.9011 - acc: 0.3122 - val_loss: 2.0137 - val_acc: 0.3602
#
# Epoch 00097: val_loss did not improve from 0.91853
# Epoch 98/100
#  - 27s - loss: 1.9170 - acc: 0.3110 - val_loss: 1.6863 - val_acc: 0.3800
#
# Epoch 00098: val_loss did not improve from 0.91853
# Epoch 99/100
#  - 26s - loss: 1.9124 - acc: 0.3084 - val_loss: 1.8429 - val_acc: 0.3414
#
# Epoch 00099: val_loss did not improve from 0.91853
# Epoch 100/100
#  - 24s - loss: 1.8993 - acc: 0.3120 - val_loss: 1.7212 - val_acc: 0.3632
#
# Epoch 00100: val_loss did not improve from 0.91853

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6782

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
