# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_in = "/Users/apoorvmalik/Desktop/GitHub/Machine Learning Algorithms/Logistic Regression/data.csv"
data = pd.read_csv(data_in, header = None)
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
plt.scatter(x = X[:, 0], y = X[:, 1], c = y)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils

model = Sequential()
model.add(Dense(128, input_shape = (2, )))
model.add(Activation('sigmoid'))
model.add(Dense(64))
model.add(Activation('sigmoid'))
model.add(Dense(32))
model.add(Activation('sigmoid'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop', metrics = ['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_32 (Dense)             (None, 128)               384
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                2080
# _________________________________________________________________
# activation_24 (Activation)   (None, 32)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 33
# ...

# %%
model.fit(X, y, epochs = 1000)
# Out:
# Epoch 1/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3545 - acc: 0.5000
# Epoch 2/1000
# 100/100 [==============================] - 0s 91us/step - loss: 0.3157 - acc: 0.5000
# Epoch 3/1000
# 100/100 [==============================] - 0s 90us/step - loss: 0.2789 - acc: 0.5000
# Epoch 4/1000
# 100/100 [==============================] - 0s 96us/step - loss: 0.2609 - acc: 0.5000
# Epoch 5/1000
# 100/100 [==============================] - 0s 128us/step - loss: 0.2533 - acc: 0.5000
# Epoch 6/1000
# 100/100 [==============================] - 0s 102us/step - loss: 0.2521 - acc: 0.5000
# Epoch 7/1000
# 100/100 [==============================] - 0s 118us/step - loss: 0.2531 - acc: 0.5000
# Epoch 8/1000
# 100/100 [==============================] - 0s 162us/step - loss: 0.2511 - acc: 0.5000
# Epoch 9/1000
# 100/100 [==============================] - 0s 101us/step - loss: 0.2504 - acc: 0.5000
# Epoch 10/1000
# ...

# %%
score = model.evaluate(X, y)
print("\nAccuracy :", score[1])
# Out:
# 100/100 [==============================] - 0s 1ms/step
#
# Accuracy : 0.93

# %%
pred = model.predict(X)
pred_opt = []
for i in pred:
    pred_opt.append(round(float(i)))
plt.scatter(x = X[:, 0], y = X[:, 1], c = pred_opt)

# %%
plt.scatter(x = X[:, 0], y = X[:, 1], c = y)
